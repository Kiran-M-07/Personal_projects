# %%
import pandas as pd

# %%
train_csv = pd.read_csv('train.csv')

# %%
data = train_csv.copy()

# %%
data['date'] = pd.to_datetime(data['date'])

# %%
data
# Out:
#             id       date    country                 store  \
# 0            0 2010-01-01     Canada     Discount Stickers
# 1            1 2010-01-01     Canada     Discount Stickers
# 2            2 2010-01-01     Canada     Discount Stickers
# 3            3 2010-01-01     Canada     Discount Stickers
# 4            4 2010-01-01     Canada     Discount Stickers
# ...        ...        ...        ...                   ...
# 230125  230125 2016-12-31  Singapore  Premium Sticker Mart
# 230126  230126 2016-12-31  Singapore  Premium Sticker Mart
# 230127  230127 2016-12-31  Singapore  Premium Sticker Mart
# 230128  230128 2016-12-31  Singapore  Premium Sticker Mart
# 230129  230129 2016-12-31  Singapore  Premium Sticker Mart
#
#                    product  num_sold
# 0        Holographic Goose       NaN
# 1                   Kaggle     973.0
# 2             Kaggle Tiers     906.0
# 3                 Kerneler     423.0
# 4       Kerneler Dark Mode     491.0
# ...                    ...       ...
# 230125   Holographic Goose     466.0
# 230126              Kaggle    2907.0
# 230127        Kaggle Tiers    2299.0
# 230128            Kerneler    1242.0
# 230129  Kerneler Dark Mode    1622.0
#
# [230130 rows x 6 columns]

# %%
data['day_of_week'] = data['date'].dt.day_name()

# %%
data
# Out:
#             id       date    country                 store  \
# 0            0 2010-01-01     Canada     Discount Stickers
# 1            1 2010-01-01     Canada     Discount Stickers
# 2            2 2010-01-01     Canada     Discount Stickers
# 3            3 2010-01-01     Canada     Discount Stickers
# 4            4 2010-01-01     Canada     Discount Stickers
# ...        ...        ...        ...                   ...
# 230125  230125 2016-12-31  Singapore  Premium Sticker Mart
# 230126  230126 2016-12-31  Singapore  Premium Sticker Mart
# 230127  230127 2016-12-31  Singapore  Premium Sticker Mart
# 230128  230128 2016-12-31  Singapore  Premium Sticker Mart
# 230129  230129 2016-12-31  Singapore  Premium Sticker Mart
#
#                    product  num_sold day_of_week
# 0        Holographic Goose       NaN      Friday
# 1                   Kaggle     973.0      Friday
# 2             Kaggle Tiers     906.0      Friday
# 3                 Kerneler     423.0      Friday
# 4       Kerneler Dark Mode     491.0      Friday
# ...                    ...       ...         ...
# 230125   Holographic Goose     466.0    Saturday
# 230126              Kaggle    2907.0    Saturday
# 230127        Kaggle Tiers    2299.0    Saturday
# 230128            Kerneler    1242.0    Saturday
# 230129  Kerneler Dark Mode    1622.0    Saturday
#
# [230130 rows x 7 columns]

# %%
data['day_of_year'] = data['date'].dt.strftime('%m-%d')

# %%
data['store'].value_counts()
# Out:
# store
# Discount Stickers       76710
# Stickers for Less       76710
# Premium Sticker Mart    76710
# Name: count, dtype: int64

# %%
data['product'].value_counts()
# Out:
# product
# Holographic Goose     46026
# Kaggle                46026
# Kaggle Tiers          46026
# Kerneler              46026
# Kerneler Dark Mode    46026
# Name: count, dtype: int64

# %%
data
# Out:
#             id       date    country                 store  \
# 0            0 2010-01-01     Canada     Discount Stickers
# 1            1 2010-01-01     Canada     Discount Stickers
# 2            2 2010-01-01     Canada     Discount Stickers
# 3            3 2010-01-01     Canada     Discount Stickers
# 4            4 2010-01-01     Canada     Discount Stickers
# ...        ...        ...        ...                   ...
# 230125  230125 2016-12-31  Singapore  Premium Sticker Mart
# 230126  230126 2016-12-31  Singapore  Premium Sticker Mart
# 230127  230127 2016-12-31  Singapore  Premium Sticker Mart
# 230128  230128 2016-12-31  Singapore  Premium Sticker Mart
# 230129  230129 2016-12-31  Singapore  Premium Sticker Mart
#
#                    product  num_sold day_of_week day_of_year
# 0        Holographic Goose       NaN      Friday       01-01
# 1                   Kaggle     973.0      Friday       01-01
# 2             Kaggle Tiers     906.0      Friday       01-01
# 3                 Kerneler     423.0      Friday       01-01
# 4       Kerneler Dark Mode     491.0      Friday       01-01
# ...                    ...       ...         ...         ...
# 230125   Holographic Goose     466.0    Saturday       12-31
# 230126              Kaggle    2907.0    Saturday       12-31
# 230127        Kaggle Tiers    2299.0    Saturday       12-31
# 230128            Kerneler    1242.0    Saturday       12-31
# 230129  Kerneler Dark Mode    1622.0    Saturday       12-31
#
# [230130 rows x 8 columns]

# %%
data.isnull().sum()
# Out:
# id                0
# date              0
# country           0
# store             0
# product           0
# num_sold       8871
# day_of_week       0
# day_of_year       0
# dtype: int64

# %%
# avg of other years for same date for same store and same product and country, avg of past 7 days

# %%
data.columns
# Out:
# Index(['id', 'date', 'country', 'store', 'product', 'num_sold', 'day_of_week',
#        'day_of_year'],
#       dtype='object')

# %%
data.describe()
# Out:
#                   id                 date       num_sold
# count  230130.000000               230130  221259.000000
# mean   115064.500000  2013-07-02 00:00:00     752.527382
# min         0.000000  2010-01-01 00:00:00       5.000000
# 25%     57532.250000  2011-10-02 00:00:00     219.000000
# 50%    115064.500000  2013-07-02 00:00:00     605.000000
# 75%    172596.750000  2015-04-02 00:00:00    1114.000000
# max    230129.000000  2016-12-31 00:00:00    5939.000000
# std     66432.953062                  NaN     690.165445

# %%
import pandas as pd

# Check for missing values
print(data.isnull().sum())

# Visualize missing values
import missingno as msno
msno.matrix(data)
# Out:
# id                0
# date              0
# country           0
# store             0
# product           0
# num_sold       8871
# day_of_week       0
# day_of_year       0
# dtype: int64
# <Axes: >

# %%
data4 = data[data['num_sold'].isna()]

# %%
data4['country'].value_counts()
# Out:
# country
# Kenya     4625
# Canada    4246
# Name: count, dtype: int64

# %%
data4[data4['store']=='Discount Stickers']['product'].value_counts()
# Out:
# product
# Holographic Goose     5114
# Kerneler                64
# Kerneler Dark Mode       1
# Name: count, dtype: int64

# %%
data[(data['country']=='Singapore')&(data['store']=='Discount Stickers')]
# Out:
#             id       date    country              store             product  \
# 75          75 2010-01-01  Singapore  Discount Stickers   Holographic Goose
# 76          76 2010-01-01  Singapore  Discount Stickers              Kaggle
# 77          77 2010-01-01  Singapore  Discount Stickers        Kaggle Tiers
# 78          78 2010-01-01  Singapore  Discount Stickers            Kerneler
# 79          79 2010-01-01  Singapore  Discount Stickers  Kerneler Dark Mode
# ...        ...        ...        ...                ...                 ...
# 230115  230115 2016-12-31  Singapore  Discount Stickers   Holographic Goose
# 230116  230116 2016-12-31  Singapore  Discount Stickers              Kaggle
# 230117  230117 2016-12-31  Singapore  Discount Stickers        Kaggle Tiers
# 230118  230118 2016-12-31  Singapore  Discount Stickers            Kerneler
# 230119  230119 2016-12-31  Singapore  Discount Stickers  Kerneler Dark Mode
#
#         num_sold day_of_week day_of_year
# 75         150.0      Friday       01-01
# 76         939.0      Friday       01-01
# 77         768.0      Friday       01-01
# 78         405.0      Friday       01-01
# 79         495.0      Friday       01-01
# ...          ...         ...         ...
# 230115     200.0    Saturday       12-31
# 230116    1259.0    Saturday       12-31
# 230117     931.0    Saturday       12-31
# 230118     556.0    Saturday       12-31
# 230119     637.0    Saturday       12-31
#
# [12785 rows x 8 columns]

# %%
data2 = data.copy()

# %%
# data2['num_sold'] = data2.groupby(['store', 'product', 'country'], group_keys=False)['num_sold'].apply(lambda x: x.bfill())

# %%
# data2.set_index('date', inplace=True)

# %%
# data2['num_sold'] = data2.groupby(['store', 'product', 'country'])['num_sold'].apply(lambda x: x.interpolate(method='linear'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /usr/local/miniconda/envs/py312_env/lib/python3.12/site-packages/pandas/core/frame.py:12687, in _reindex_for_setitem(value, index)
#   12686 try:
# > 12687     reindexed_value = value.reindex(index)._values
#   12688 except ValueError as err:
#   12689     # raised in MultiIndex.from_tuples, see test_insert_error_msmgs
#
# File /usr/local/miniconda/envs/py312_env/lib/python3.12/site-packages/pandas/core/series.py:5153, in Series.reindex(self, index, axis, method, copy, level, fill_value, limit, tolerance)
#    5136 @doc(
#    5137     NDFrame.reindex,  # type: ignore[has-type]
#    5138     klass=_shared_doc_kwargs["klass"],
#    (...)
#    5151     tolerance=None,
#    5152 ) -> Series:
# -> 5153     return super().reindex(
#    5154         index=index,
#    5155         method=method,
#    5156         copy=copy,
#    5157         level=level,
#    5158         fill_value=fill_value,
#    5159         limit=limit,
#    5160         tolerance=tolerance,
#    5161     )
#
# File /usr/local/miniconda/envs/py312_env/lib/python3.12/site-packages/pandas/core/generic.py:5610, in NDFrame.reindex(self, labels, index, columns, axis, method, copy, level, fill_value, limit, tolerance)
#    5609 # perform the reindex on the axes
# -> 5610 return self._reindex_axes(
#    5611     axes, level, limit, tolerance, method, fill_value, copy
#    5612 ).__finalize__(self, method="reindex")
#
# File /usr/local/miniconda/envs/py312_env/lib/python3.12/site-packages/pandas/core/generic.py:5633, in NDFrame._reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    5632 ax = self._get_axis(a)
# -> 5633 new_index, indexer = ax.reindex(
#    5634     labels, level=level, limit=limit, tolerance=tolerance, method=method
#    5635 )
#    5637 axis = self._get_axis_number(a)
#
# File /usr/local/miniconda/envs/py312_env/lib/python3.12/site-packages/pandas/core/indexes/base.py:4433, in Index.reindex(self, target, method, level, limit, tolerance)
#    4431             indexer, _ = self.get_indexer_non_unique(target)
# -> 4433 target = self._wrap_reindex_result(target, indexer, preserve_names)
#    4434 return target, indexer
#
# File /usr/local/miniconda/envs/py312_env/lib/python3.12/site-packages/pandas/core/indexes/multi.py:2717, in MultiIndex._wrap_reindex_result(self, target, indexer, preserve_names)
#    2716 try:
# -> 2717     target = MultiIndex.from_tuples(target)
#    2718 except TypeError:
#    2719     # not all tuples, see test_constructor_dict_multiindex_reindex_flat
#
# File /usr/local/miniconda/envs/py312_env/lib/python3.12/site-packages/pandas/core/indexes/multi.py:222, in names_compat.<locals>.new_meth(self_or_cls, *args, **kwargs)
#     220     kwargs["names"] = kwargs.pop("name")
# --> 222 return meth(self_or_cls, *args, **kwargs)
#
# File /usr/local/miniconda/envs/py312_env/lib/python3.12/site-packages/pandas/core/indexes/multi.py:617, in MultiIndex.from_tuples(cls, tuples, sortorder, names)
#     615         tuples = np.asarray(tuples._values)
# --> 617     arrays = list(lib.tuples_to_object_array(tuples).T)
#     618 elif isinstance(tuples, list):
#
# File lib.pyx:3029, in pandas._libs.lib.tuples_to_object_array()
#
# ValueError: Buffer dtype mismatch, expected 'Python object' but got 'long'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_15944/799239336.py in ?()
# ----> 1 data2['num_sold'] = data2.groupby(['store', 'product', 'country'])['num_sold'].apply(lambda x: x.interpolate(method='linear'))
#
# /usr/local/miniconda/envs/py312_env/lib/python3.12/site-packages/pandas/core/frame.py in ?(self, key, value)
#    4307             # Column to set is duplicated
#    4308             self._setitem_array([key], value)
#    4309         else:
#    4310             # set column
# -> 4311             self._set_item(key, value)
#
# /usr/local/miniconda/envs/py312_env/lib/python3.12/site-packages/pandas/core/frame.py in ?(self, key, value)
#    4520
#    4521         Series/TimeSeries will be conformed to the DataFrames index to
#    4522         ensure homogeneity.
#    4523         """
# -> 4524         value, refs = self._sanitize_column(value)
#    4525
#    4526         if (
#    4527             key in self.columns
#
# /usr/local/miniconda/envs/py312_env/lib/python3.12/site-packages/pandas/core/frame.py in ?(self, value)
#    5259         assert not isinstance(value, DataFrame)
#    5260         if is_dict_like(value):
#    5261             if not isinstance(value, Series):
#    5262                 value = Series(value)
# -> 5263             return _reindex_for_setitem(value, self.index)
#    5264
#    5265         if is_list_like(value):
#    5266             com.require_length_match(value, self.index)
#
# /usr/local/miniconda/envs/py312_env/lib/python3.12/site-packages/pandas/core/frame.py in ?(value, index)
#   12690         if not value.index.is_unique:
#   12691             # duplicate axis
#   12692             raise err
#   12693
# > 12694         raise TypeError(
#   12695             "incompatible index of inserted column with frame index"
#   12696         ) from err
#   12697     return reindexed_value, None
#
# TypeError: incompatible index of inserted column with frame index

# %%
data2['num_sold'] = data2.groupby(['store', 'product', 'country'], group_keys=False)['num_sold'].apply(lambda x: x.bfill().ffill())

# %%
# data2['num_sold'] = data2.groupby(['store', 'product', 'country'])['num_sold'].apply(lambda x: x.interpolate(method='linear')).reset_index(level=[0, 1, 2], drop=True)

# %%
data2
# Out:
#             id       date    country                 store  \
# 0            0 2010-01-01     Canada     Discount Stickers
# 1            1 2010-01-01     Canada     Discount Stickers
# 2            2 2010-01-01     Canada     Discount Stickers
# 3            3 2010-01-01     Canada     Discount Stickers
# 4            4 2010-01-01     Canada     Discount Stickers
# ...        ...        ...        ...                   ...
# 230125  230125 2016-12-31  Singapore  Premium Sticker Mart
# 230126  230126 2016-12-31  Singapore  Premium Sticker Mart
# 230127  230127 2016-12-31  Singapore  Premium Sticker Mart
# 230128  230128 2016-12-31  Singapore  Premium Sticker Mart
# 230129  230129 2016-12-31  Singapore  Premium Sticker Mart
#
#                    product  num_sold day_of_week day_of_year
# 0        Holographic Goose       NaN      Friday       01-01
# 1                   Kaggle     973.0      Friday       01-01
# 2             Kaggle Tiers     906.0      Friday       01-01
# 3                 Kerneler     423.0      Friday       01-01
# 4       Kerneler Dark Mode     491.0      Friday       01-01
# ...                    ...       ...         ...         ...
# 230125   Holographic Goose     466.0    Saturday       12-31
# 230126              Kaggle    2907.0    Saturday       12-31
# 230127        Kaggle Tiers    2299.0    Saturday       12-31
# 230128            Kerneler    1242.0    Saturday       12-31
# 230129  Kerneler Dark Mode    1622.0    Saturday       12-31
#
# [230130 rows x 8 columns]

# %%
data2.isnull().sum()
# Out:
# id                0
# date              0
# country           0
# store             0
# product           0
# num_sold       5114
# day_of_week       0
# day_of_year       0
# dtype: int64

# %%
data2.loc[
    (data2['country'].isin(['Canada', 'Kenya'])) & 
    (data2['store'] == 'Discount Stickers') & 
    (data2['product'] == 'Holographic Goose'), 
    'num_sold'
] = 0

# %%
data2.isnull().sum()
# Out:
# id             0
# date           0
# country        0
# store          0
# product        0
# num_sold       0
# day_of_week    0
# day_of_year    0
# dtype: int64

# %%
data2
# Out:
#             id       date    country                 store  \
# 0            0 2010-01-01     Canada     Discount Stickers
# 1            1 2010-01-01     Canada     Discount Stickers
# 2            2 2010-01-01     Canada     Discount Stickers
# 3            3 2010-01-01     Canada     Discount Stickers
# 4            4 2010-01-01     Canada     Discount Stickers
# ...        ...        ...        ...                   ...
# 230125  230125 2016-12-31  Singapore  Premium Sticker Mart
# 230126  230126 2016-12-31  Singapore  Premium Sticker Mart
# 230127  230127 2016-12-31  Singapore  Premium Sticker Mart
# 230128  230128 2016-12-31  Singapore  Premium Sticker Mart
# 230129  230129 2016-12-31  Singapore  Premium Sticker Mart
#
#                    product  num_sold day_of_week day_of_year
# 0        Holographic Goose       0.0      Friday       01-01
# 1                   Kaggle     973.0      Friday       01-01
# 2             Kaggle Tiers     906.0      Friday       01-01
# 3                 Kerneler     423.0      Friday       01-01
# 4       Kerneler Dark Mode     491.0      Friday       01-01
# ...                    ...       ...         ...         ...
# 230125   Holographic Goose     466.0    Saturday       12-31
# 230126              Kaggle    2907.0    Saturday       12-31
# 230127        Kaggle Tiers    2299.0    Saturday       12-31
# 230128            Kerneler    1242.0    Saturday       12-31
# 230129  Kerneler Dark Mode    1622.0    Saturday       12-31
#
# [230130 rows x 8 columns]

# %%
data2.to_excel('train_1.xlsx')

# %%
# import numpy as np

# def detect_outliers(group):
#     mean = group['num_sold'].mean()
#     std = group['num_sold'].std()

#     group['outlier_level'] = 'Normal'  # Default label
    
#     group.loc[group['num_sold'] > mean + std, 'outlier_level'] = 'P3'
#     group.loc[group['num_sold'] > mean + 2 * std, 'outlier_level'] = 'P2'
#     group.loc[group['num_sold'] > mean + 3 * std, 'outlier_level'] = 'P1'

#     return group

# # Apply to each combination of 'country', 'store', 'product'
# data2 = data2.groupby(['country', 'store', 'product'], group_keys=False).apply(detect_outliers)

# # Check outlier summary
# print(data2['outlier_level'].value_counts())
# Out:
# outlier_level
# Normal    194904
# P3         27172
# P2          6730
# P1          1324
# Name: count, dtype: int64
# /tmp/ipykernel_15944/3442260545.py:16: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   data2 = data2.groupby(['country', 'store', 'product'], group_keys=False).apply(detect_outliers)

# %%
# import pandas as pd
# import numpy as np

# # Load data
# # df = pd.read_csv("your_data.csv")  # Replace with actual file path

# # Function to detect holidays (simple heuristic: extremely high sales volume)
# def identify_holidays(group, threshold=0.95):
#     """Identifies possible holidays where sales are unusually high (top 5% quantile)."""
#     holiday_threshold = group["num_sold"].quantile(threshold)
#     group["is_holiday"] = group["num_sold"] >= holiday_threshold
#     return group

# # Identify holidays for each (country, store, product)
# data2 = data2.groupby(["country", "store", "product"], group_keys=False).apply(identify_holidays)

# # Function to detect anomalies after removing seasonality and holidays
# def detect_non_seasonal_anomalies(group):
#     # Exclude holidays before computing stats
#     non_holiday_data = group[~group["is_holiday"]]
    
#     if len(non_holiday_data) < 3:  # Avoid computation on too few data points
#         group["non_seasonal_anomaly"] = "Normal"
#         return group
    
#     # Compute mean and std on non-holiday data
#     mean = non_holiday_data["num_sold"].mean()
#     std = non_holiday_data["num_sold"].std()
    
#     # Classify anomalies
#     def classify(value):
#         if abs(value - mean) > 3 * std:
#             return "P1"
#         elif abs(value - mean) > 2 * std:
#             return "P2"
#         elif abs(value - mean) > std:
#             return "P3"
#         return "Normal"
    
#     group["non_seasonal_anomaly"] = group["num_sold"].apply(classify)
#     return group

# # Apply anomaly detection for each (country, store, product, day_of_year)
# data2 = data2.groupby(["country", "store", "product", "day_of_year"], group_keys=False).apply(detect_non_seasonal_anomalies)

# # Save results
# data2.to_csv("non_seasonal_anomaly_detected_data.csv", index=False)
# print(data2.head())  # Display first few rows
# Out:
# /tmp/ipykernel_15944/990924543.py:15: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   data2 = data2.groupby(["country", "store", "product"], group_keys=False).apply(identify_holidays)
# /tmp/ipykernel_15944/990924543.py:44: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   data2 = data2.groupby(["country", "store", "product", "day_of_year"], group_keys=False).apply(detect_non_seasonal_anomalies)
#    id       date country              store             product  num_sold  \
# 0   0 2010-01-01  Canada  Discount Stickers   Holographic Goose       0.0
# 1   1 2010-01-01  Canada  Discount Stickers              Kaggle     973.0
# 2   2 2010-01-01  Canada  Discount Stickers        Kaggle Tiers     906.0
# 3   3 2010-01-01  Canada  Discount Stickers            Kerneler     423.0
# 4   4 2010-01-01  Canada  Discount Stickers  Kerneler Dark Mode     491.0
#
#   day_of_week day_of_year  is_holiday non_seasonal_anomaly
# 0      Friday       01-01        True               Normal
# 1      Friday       01-01        True                   P1
# 2      Friday       01-01        True                   P1
# 3      Friday       01-01       False                   P3
# 4      Friday       01-01       False                   P3

# %%
# public_holidays = [
#     "01-01", "07-04", "12-25"  # New Year's, Independence Day, Christmas (example)
# ]

# # Flag public holidays
# data2["is_holiday"] = data2["day_of_year"].isin(public_holidays)


# def detect_non_seasonal_anomalies(group):
#     # Compute mean and std for same day_of_year to remove seasonal impact
#     season_mean_std = group.groupby("day_of_year")["num_sold"].agg(
#         mean_seasonal="mean", std_seasonal="std"
#     ).reset_index()

#     # Merge seasonal data
#     group = group.merge(season_mean_std, on="day_of_year", how="left")

#     # Remove seasonal impact
#     group["detrended_sales"] = group["num_sold"] - group["mean_seasonal"]

#     # Compute statistics for detrended sales (excluding holidays)
#     non_holiday_group = group[~group["is_holiday"]]
#     overall_mean = non_holiday_group["detrended_sales"].mean()
#     overall_std = non_holiday_group["detrended_sales"].std()

#     # Function to classify anomalies
#     def classify(value):
#         if abs(value - overall_mean) > 3 * overall_std:
#             return "P1"
#         elif abs(value - overall_mean) > 2 * overall_std:
#             return "P2"
#         elif abs(value - overall_mean) > overall_std:
#             return "P3"
#         return "Normal"

#     # Apply classification (only detect anomalies on non-holidays)
#     group["non_seasonal_anomaly"] = group.apply(
#         lambda row: classify(row["detrended_sales"]) if not row["is_holiday"] else "Holiday", axis=1
#     )

#     return group.drop(columns=["detrended_sales"])

# # Apply detection for each (country, store, product) group
# data2 = detect_non_seasonal_anomalies(data2)

# # Save results
# data2.to_csv("non_seasonal_anomalies.csv", index=False)

# # Display first few rows
# print(data2.head())
# Out:
#    id       date country              store             product  num_sold  \
# 0   0 2010-01-01  Canada  Discount Stickers   Holographic Goose       0.0
# 1   1 2010-01-01  Canada  Discount Stickers              Kaggle     973.0
# 2   2 2010-01-01  Canada  Discount Stickers        Kaggle Tiers     906.0
# 3   3 2010-01-01  Canada  Discount Stickers            Kerneler     423.0
# 4   4 2010-01-01  Canada  Discount Stickers  Kerneler Dark Mode     491.0
#
#   day_of_week day_of_year  is_holiday  mean_seasonal  std_seasonal  \
# 0      Friday       01-01        True      888.21746    840.899402
# 1      Friday       01-01        True      888.21746    840.899402
# 2      Friday       01-01        True      888.21746    840.899402
# 3      Friday       01-01        True      888.21746    840.899402
# 4      Friday       01-01        True      888.21746    840.899402
#
#   non_seasonal_anomaly
# 0              Holiday
# 1              Holiday
# 2              Holiday
# 3              Holiday
# 4              Holiday

# %%
# import pandas as pd

# # Load data
# # df = pd.read_csv("your_data.csv")  # Replace with actual file path if needed

# # Function to classify anomalies
# def detect_anomalies(group):
#     # Global statistics for the entire group
#     global_mean = group["num_sold"].mean()
#     global_std = group["num_sold"].std()
    
#     # Function to classify based on global comparison
#     def classify_global(value):
#         if abs(value - global_mean) > 3 * global_std:
#             return "P1"
#         elif abs(value - global_mean) > 2 * global_std:
#             return "P2"
#         elif abs(value - global_mean) > global_std:
#             return "P3"
#         return "Normal"
    
#     group["global_anomaly"] = group["num_sold"].apply(classify_global)
    
#     # Detect anomalies within each day_of_year
#     def detect_daily_anomalies(day_group):
#         daily_mean = day_group["num_sold"].mean()
#         daily_std = day_group["num_sold"].std()
        
#         def classify_daily(value):
#             if abs(value - daily_mean) > 3 * daily_std:
#                 return "P1"
#             elif abs(value - daily_mean) > 2 * daily_std:
#                 return "P2"
#             elif abs(value - daily_mean) > daily_std:
#                 return "P3"
#             return "Normal"
        
#         day_group["daily_anomaly"] = day_group["num_sold"].apply(classify_daily)
#         return day_group

#     group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
    
#     return group

# # Apply detection for each (country, store, product) group
# data2 = data2.groupby(["country", "store", "product"], group_keys=False).apply(detect_anomalies)

# # Save or display results
# data2.to_csv("anomaly_detected_data.csv", index=False)  # Save results
# print(data2.head())  # Display first few rows
# Out:
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group = group.groupby("day_of_year", group_keys=False).apply(detect_daily_anomalies)
# /tmp/ipykernel_15944/3721777727.py:46: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   data2 = data2.groupby(["country", "store", "product"], group_keys=False).apply(detect_anomalies)
#    id       date country              store             product  num_sold  \
# 0   0 2010-01-01  Canada  Discount Stickers   Holographic Goose       0.0
# 1   1 2010-01-01  Canada  Discount Stickers              Kaggle     973.0
# 2   2 2010-01-01  Canada  Discount Stickers        Kaggle Tiers     906.0
# 3   3 2010-01-01  Canada  Discount Stickers            Kerneler     423.0
# 4   4 2010-01-01  Canada  Discount Stickers  Kerneler Dark Mode     491.0
#
#   day_of_week day_of_year global_anomaly daily_anomaly
# 0      Friday       01-01         Normal        Normal
# 1      Friday       01-01             P2        Normal
# 2      Friday       01-01             P1            P3
# 3      Friday       01-01             P3        Normal
# 4      Friday       01-01             P3        Normal

# %%
# ls
# Out:
# Eywa.ipynb                            mynotebook1.ipynb
# GS reverse funnel-4.csv               nbeats.ipynb
# GS reverse funnel-5.csv               notebookbc3e84965d.ipynb
# GSRevfunnelLLM.ipynb                  pagesectionvisibilityexp.ipynb
# GSreversefunnel.ipynb                 results/
# GSreversefunnelLLM.ipynb              shared-workspace@
# Pagesectionvisibilityexp.ipynb        spark.ipynb
# QA.ipynb                              test_nb_v1.ipynb
# QAmodel (2).ipynb                     train.csv
# QAmodel.ipynb                         train_1.xlsx
# SQLGPTEywa.ipynb                      untitled-1.ipynb
# Untitled.ipynb                        untitled-10.ipynb
# Untitled1.ipynb                       untitled-11.ipynb
# Untitled2.ipynb                       untitled-12.ipynb
# Untitled3.ipynb                       untitled-13.ipynb
# Untitled4.ipynb                       untitled-14.ipynb
# Untitled5.ipynb                       untitled-15.ipynb
# Untitled6.ipynb                       untitled-16.ipynb
# Untitled7.ipynb                       untitled-17.ipynb
# Untitled8.ipynb                       untitled-18.ipynb
# Untitled9.ipynb                       untitled-19.ipynb
# Utility.ipynb                         untitled-2.ipynb
# V0.9.ipynb                            untitled-20.ipynb
# V0.91.ipynb                           untitled-3.ipynb
# V0.92.ipynb                           untitled-4.ipynb
# V0.93.ipynb                           untitled-5.ipynb
# acd_pipeline_analysis_nitheesh.ipynb  untitled-6.ipynb
# ace-pipeline-test-spark.ipynb         untitled-7.ipynb
# examples@                             untitled-8.ipynb
# gph-ges.ipynb                         untitled-9.ipynb
# logs/

# %%
import numpy as np

# %%
# data3 = data2[data2['num_sold'].isna()]

# %%
# data3[data3['country']=='Canada']
# Out:
#             id       date country              store            product  \
# 0            0 2010-01-01  Canada  Discount Stickers  Holographic Goose
# 90          90 2010-01-02  Canada  Discount Stickers  Holographic Goose
# 180        180 2010-01-03  Canada  Discount Stickers  Holographic Goose
# 270        270 2010-01-04  Canada  Discount Stickers  Holographic Goose
# 360        360 2010-01-05  Canada  Discount Stickers  Holographic Goose
# ...        ...        ...     ...                ...                ...
# 229680  229680 2016-12-27  Canada  Discount Stickers  Holographic Goose
# 229770  229770 2016-12-28  Canada  Discount Stickers  Holographic Goose
# 229860  229860 2016-12-29  Canada  Discount Stickers  Holographic Goose
# 229950  229950 2016-12-30  Canada  Discount Stickers  Holographic Goose
# 230040  230040 2016-12-31  Canada  Discount Stickers  Holographic Goose
#
#         num_sold day_of_week day_of_year
# 0            NaN      Friday       01-01
# 90           NaN    Saturday       01-02
# 180          NaN      Sunday       01-03
# 270          NaN      Monday       01-04
# 360          NaN     Tuesday       01-05
# ...          ...         ...         ...
# 229680       NaN     Tuesday       12-27
# 229770       NaN   Wednesday       12-28
# 229860       NaN    Thursday       12-29
# 229950       NaN      Friday       12-30
# 230040       NaN    Saturday       12-31
#
# [2557 rows x 8 columns]

# %%
# df = data.groupby(['day_of_year', 'country'])['num_sold'].sum()

# %%
# df

# %%
# stationarity

# %%
# y = f(t) = sin(t)

# %%
# ARIMAx SARIMA Prophet

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming `data` is your DataFrame

# Step 1: Group by 'day_of_year' and 'country', and sum up 'num_sold'
data_grouped = data.groupby(['day_of_year', 'country'], as_index=False)['num_sold'].sum()

# Step 2: Pivot the data so that each country is a column
data_pivoted = data_grouped.pivot(index='day_of_year', columns='country', values='num_sold')

# Step 3: Plot the data
plt.figure(figsize=(14, 8))
data_pivoted.plot(kind='line', marker='o', figsize=(14, 8))

# Customize the plot
plt.title('Total Sales by Day of Year and Country', fontsize=16)
plt.xlabel('Day of Year', fontsize=14)
plt.ylabel('Number of Units Sold', fontsize=14)
plt.xticks(rotation=45)
plt.legend(title='Country', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()

# Show the plot
plt.show()

# %%
# import pandas as pd


# df = pd.DataFrame(data_grouped)

# # Find the day_of_year where num_sold is maximum for each country
# max_days = df.loc[df.groupby('country')['num_sold'].idxmax()]

# # Find the day_of_year where num_sold is minimum for each country
# min_days = df.loc[df.groupby('country')['num_sold'].idxmin()]

# # Display the results
# print("Days with Maximum Sales for Each Country:")
# print(max_days)

# print("\nDays with Minimum Sales for Each Country:")
# print(min_days)

# %%
data_grouped[data_grouped['country']=='Norway'].describe()

# %%
# no anomaly if data within mean +- std

# %%
# P3 anomaly if data > mean +- std, P2 if data > mean +- 2*std, P1 if data > mean +- 3*std

# %%
# null values, outliers, normalization

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming `data` is your DataFrame

# Step 1: Group by 'day_of_year' and 'country', and sum up 'num_sold'
data_grouped = data.groupby(['date', 'country'], as_index=False)['num_sold'].sum()

data_pivoted = data_grouped.pivot(index='date', columns='country', values='num_sold')

# Step 3: Plot the data
plt.figure(figsize=(14, 8))
data_pivoted.plot(kind='line', marker='o', figsize=(14, 8))

# Customize the plot
plt.title('Total Sales by Day of Year and Country', fontsize=16)
plt.xlabel('Day of Year', fontsize=14)
plt.ylabel('Number of Units Sold', fontsize=14)
plt.xticks(rotation=45)
plt.legend(title='Country', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()

# Show the plot
plt.show()

# %%
# data2["num_sold_zscore"] = df.groupby(["country", "store", "product"])["num_sold"].transform(
#     lambda x: (x - x.mean()) / x.std()
# )

# %%
# import pandas as pd
# import matplotlib.pyplot as plt
# from prophet import Prophet

# # # Load data
# # data2 = pd.read_csv("your_data.csv")  # Replace with actual file path

# # # Convert date to datetime format
# # da["date"] = pd.to_datetime(df["date"])

# # Function to train Prophet and forecast
# def forecast_sales(group):
#     # Rename columns for Prophet
#     prophet_df = group.rename(columns={"date": "ds", "num_sold": "y"})
    
#     # Initialize Prophet model
#     model = Prophet()
#     model.fit(prophet_df)
    
#     # Generate future dates (next 90 days)
#     future = model.make_future_dataframe(periods=90)
    
#     # Make predictions
#     forecast = model.predict(future)
    
#     # Merge with original data for visualization
#     forecast = forecast[["ds", "yhat", "yhat_lower", "yhat_upper"]]
#     forecast["country"] = group["country"].iloc[0]
#     forecast["store"] = group["store"].iloc[0]
#     forecast["product"] = group["product"].iloc[0]
    
#     return forecast

# # Apply forecasting for each (country, store, product) group
# forecasts = data2.groupby(["country", "store", "product"], group_keys=False).apply(forecast_sales)

# # Save results
# forecasts.to_csv("prophet_forecasts.csv", index=False)

# # Plot example (change country/store/product to view different results)
# example_group = data2[(data2["country"] == "Canada") & 
#                    (data2["store"] == "Discount Stickers") & 
#                    (data2["product"] == "Kaggle")]

# forecast_example = forecasts[(forecasts["country"] == "Canada") & 
#                              (forecasts["store"] == "Discount Stickers") & 
#                              (forecasts["product"] == "Kaggle")]

# plt.figure(figsize=(12, 6))
# plt.plot(example_group["date"], example_group["num_sold"], label="Actual Sales")
# plt.plot(forecast_example["ds"], forecast_example["yhat"], label="Forecast", linestyle="dashed")
# plt.fill_between(forecast_example["ds"], forecast_example["yhat_lower"], forecast_example["yhat_upper"], alpha=0.2)
# plt.legend()
# plt.title("Prophet Forecast for Canada - Discount Stickers - Kaggle")
# plt.xlabel("Date")
# plt.ylabel("Number Sold")
# plt.show()
# Out:
# Importing plotly failed. Interactive plots will not work.
# 16:37:43 - cmdstanpy - INFO - Chain [1] start processing
# 16:37:44 - cmdstanpy - INFO - Chain [1] done processing
# 16:37:44 - cmdstanpy - INFO - Chain [1] start processing
# 16:37:45 - cmdstanpy - INFO - Chain [1] done processing
# 16:37:45 - cmdstanpy - INFO - Chain [1] start processing
# 16:37:46 - cmdstanpy - INFO - Chain [1] done processing
# 16:37:47 - cmdstanpy - INFO - Chain [1] start processing
# 16:37:48 - cmdstanpy - INFO - Chain [1] done processing
# 16:37:48 - cmdstanpy - INFO - Chain [1] start processing
# 16:37:49 - cmdstanpy - INFO - Chain [1] done processing
# 16:37:49 - cmdstanpy - INFO - Chain [1] start processing
# 16:37:50 - cmdstanpy - INFO - Chain [1] done processing
# 16:37:51 - cmdstanpy - INFO - Chain [1] start processing
# 16:37:52 - cmdstanpy - INFO - Chain [1] done processing
# 16:37:52 - cmdstanpy - INFO - Chain [1] start processing
# 16:37:53 - cmdstanpy - INFO - Chain [1] done processing
# 16:37:54 - cmdstanpy - INFO - Chain [1] start processing
# 16:37:54 - cmdstanpy - INFO - Chain [1] done processing
# 16:37:55 - cmdstanpy - INFO - Chain [1] start processing
# 16:37:56 - cmdstanpy - INFO - Chain [1] done processing
# 16:37:56 - cmdstanpy - INFO - Chain [1] start processing
# 16:37:58 - cmdstanpy - INFO - Chain [1] done processing
# 16:37:58 - cmdstanpy - INFO - Chain [1] start processing
# 16:37:59 - cmdstanpy - INFO - Chain [1] done processing
# 16:38:00 - cmdstanpy - INFO - Chain [1] start processing
# 16:38:00 - cmdstanpy - INFO - Chain [1] done processing
# 16:38:01 - cmdstanpy - INFO - Chain [1] start processing
# 16:38:02 - cmdstanpy - INFO - Chain [1] done processing
# 16:38:02 - cmdstanpy - INFO - Chain [1] start processing
# 16:38:03 - cmdstanpy - INFO - Chain [1] done processing
# 16:38:04 - cmdstanpy - INFO - Chain [1] start processing
# 16:38:05 - cmdstanpy - INFO - Chain [1] done processing
# 16:38:05 - cmdstanpy - INFO - Chain [1] start processing
# 16:38:06 - cmdstanpy - INFO - Chain [1] done processing
# 16:38:07 - cmdstanpy - INFO - Chain [1] start processing
# 16:38:08 - cmdstanpy - INFO - Chain [1] done processing
# 16:38:09 - cmdstanpy - INFO - Chain [1] start processing
# 16:38:10 - cmdstanpy - INFO - Chain [1] done processing
# 16:38:10 - cmdstanpy - INFO - Chain [1] start processing
# 16:38:11 - cmdstanpy - INFO - Chain [1] done processing
# 16:38:12 - cmdstanpy - INFO - Chain [1] start processing
# 16:38:13 - cmdstanpy - INFO - Chain [1] done processing
# 16:38:13 - cmdstanpy - INFO - Chain [1] start processing
# 16:38:14 - cmdstanpy - INFO - Chain [1] done processing
# 16:38:15 - cmdstanpy - INFO - Chain [1] start processing
# 16:38:15 - cmdstanpy - INFO - Chain [1] done processing
# 16:38:16 - cmdstanpy - INFO - Chain [1] start processing
# 16:38:17 - cmdstanpy - INFO - Chain [1] done processing
# 16:38:18 - cmdstanpy - INFO - Chain [1] start processing
# 16:38:18 - cmdstanpy - INFO - Chain [1] done processing
# 16:38:19 - cmdstanpy - INFO - Chain [1] start processing
# 16:38:20 - cmdstanpy - INFO - Chain [1] done processing
# 16:38:20 - cmdstanpy - INFO - Chain [1] start processing
# 16:38:21 - cmdstanpy - INFO - Chain [1] done processing
# 16:38:22 - cmdstanpy - INFO - Chain [1] start processing
# 16:38:23 - cmdstanpy - INFO - Chain [1] done processing
# 16:38:23 - cmdstanpy - INFO - Chain [1] start processing
# 16:38:24 - cmdstanpy - INFO - Chain [1] done processing
# 16:38:25 - cmdstanpy - INFO - Chain [1] start processing
# 16:38:25 - cmdstanpy - INFO - Chain [1] done processing
# 16:38:26 - cmdstanpy - INFO - Chain [1] start processing
# 16:38:27 - cmdstanpy - INFO - Chain [1] done processing
# 16:38:27 - cmdstanpy - INFO - Chain [1] start processing
# 16:38:28 - cmdstanpy - INFO - Chain [1] done processing
# 16:38:29 - cmdstanpy - INFO - Chain [1] start processing
# 16:38:30 - cmdstanpy - INFO - Chain [1] done processing
# 16:38:30 - cmdstanpy - INFO - Chain [1] start processing
# 16:38:31 - cmdstanpy - INFO - Chain [1] done processing
# 16:38:32 - cmdstanpy - INFO - Chain [1] start processing
# 16:38:33 - cmdstanpy - INFO - Chain [1] done processing
# 16:38:34 - cmdstanpy - INFO - Chain [1] start processing
# 16:38:34 - cmdstanpy - INFO - Chain [1] done processing
# 16:38:35 - cmdstanpy - INFO - Chain [1] start processing
# 16:38:36 - cmdstanpy - INFO - Chain [1] done processing
# 16:38:37 - cmdstanpy - INFO - Chain [1] start processing
# 16:38:37 - cmdstanpy - INFO - Chain [1] done processing
# 16:38:38 - cmdstanpy - INFO - Chain [1] start processing
# 16:38:39 - cmdstanpy - INFO - Chain [1] done processing
# 16:38:39 - cmdstanpy - INFO - Chain [1] start processing
# 16:38:40 - cmdstanpy - INFO - Chain [1] done processing
# 16:38:41 - cmdstanpy - INFO - Chain [1] start processing
# 16:38:41 - cmdstanpy - INFO - Chain [1] done processing
# 16:38:42 - cmdstanpy - INFO - Chain [1] start processing
# 16:38:43 - cmdstanpy - INFO - Chain [1] done processing
# 16:38:44 - cmdstanpy - INFO - Chain [1] start processing
# 16:38:44 - cmdstanpy - INFO - Chain [1] done processing
# 16:38:45 - cmdstanpy - INFO - Chain [1] start processing
# 16:38:45 - cmdstanpy - INFO - Chain [1] done processing
# 16:38:47 - cmdstanpy - INFO - Chain [1] start processing
# 16:38:47 - cmdstanpy - INFO - Chain [1] done processing
# 16:38:48 - cmdstanpy - INFO - Chain [1] start processing
# 16:38:48 - cmdstanpy - INFO - Chain [1] done processing
# 16:38:49 - cmdstanpy - INFO - Chain [1] start processing
# 16:38:50 - cmdstanpy - INFO - Chain [1] done processing
# 16:38:50 - cmdstanpy - INFO - Chain [1] start processing
# 16:38:51 - cmdstanpy - INFO - Chain [1] done processing
# 16:38:51 - cmdstanpy - INFO - Chain [1] start processing
# 16:38:52 - cmdstanpy - INFO - Chain [1] done processing
# 16:38:53 - cmdstanpy - INFO - Chain [1] start processing
# 16:38:53 - cmdstanpy - INFO - Chain [1] done processing
# 16:38:54 - cmdstanpy - INFO - Chain [1] start processing
# 16:38:54 - cmdstanpy - INFO - Chain [1] done processing
# 16:38:55 - cmdstanpy - INFO - Chain [1] start processing
# 16:38:56 - cmdstanpy - INFO - Chain [1] done processing
# 16:38:56 - cmdstanpy - INFO - Chain [1] start processing
# 16:38:57 - cmdstanpy - INFO - Chain [1] done processing
# 16:38:57 - cmdstanpy - INFO - Chain [1] start processing
# 16:38:58 - cmdstanpy - INFO - Chain [1] done processing
# 16:38:58 - cmdstanpy - INFO - Chain [1] start processing
# 16:38:59 - cmdstanpy - INFO - Chain [1] done processing
# 16:38:59 - cmdstanpy - INFO - Chain [1] start processing
# 16:39:00 - cmdstanpy - INFO - Chain [1] done processing
# 16:39:01 - cmdstanpy - INFO - Chain [1] start processing
# 16:39:01 - cmdstanpy - INFO - Chain [1] done processing
# 16:39:02 - cmdstanpy - INFO - Chain [1] start processing
# 16:39:02 - cmdstanpy - INFO - Chain [1] done processing
# 16:39:03 - cmdstanpy - INFO - Chain [1] start processing
# 16:39:04 - cmdstanpy - INFO - Chain [1] done processing
# 16:39:05 - cmdstanpy - INFO - Chain [1] start processing
# 16:39:06 - cmdstanpy - INFO - Chain [1] done processing
# 16:39:07 - cmdstanpy - INFO - Chain [1] start processing
# 16:39:08 - cmdstanpy - INFO - Chain [1] done processing
# 16:39:08 - cmdstanpy - INFO - Chain [1] start processing
# 16:39:09 - cmdstanpy - INFO - Chain [1] done processing
# 16:39:10 - cmdstanpy - INFO - Chain [1] start processing
# 16:39:10 - cmdstanpy - INFO - Chain [1] done processing
# 16:39:11 - cmdstanpy - INFO - Chain [1] start processing
# 16:39:12 - cmdstanpy - INFO - Chain [1] done processing
# 16:39:12 - cmdstanpy - INFO - Chain [1] start processing
# 16:39:13 - cmdstanpy - INFO - Chain [1] done processing
# 16:39:14 - cmdstanpy - INFO - Chain [1] start processing
# 16:39:15 - cmdstanpy - INFO - Chain [1] done processing
# 16:39:16 - cmdstanpy - INFO - Chain [1] start processing
# 16:39:16 - cmdstanpy - INFO - Chain [1] done processing
# 16:39:17 - cmdstanpy - INFO - Chain [1] start processing
# 16:39:18 - cmdstanpy - INFO - Chain [1] done processing
# 16:39:18 - cmdstanpy - INFO - Chain [1] start processing
# 16:39:19 - cmdstanpy - INFO - Chain [1] done processing
# 16:39:20 - cmdstanpy - INFO - Chain [1] start processing
# 16:39:21 - cmdstanpy - INFO - Chain [1] done processing
# 16:39:21 - cmdstanpy - INFO - Chain [1] start processing
# 16:39:22 - cmdstanpy - INFO - Chain [1] done processing
# 16:39:23 - cmdstanpy - INFO - Chain [1] start processing
# 16:39:23 - cmdstanpy - INFO - Chain [1] done processing
# 16:39:24 - cmdstanpy - INFO - Chain [1] start processing
# 16:39:25 - cmdstanpy - INFO - Chain [1] done processing
# 16:39:25 - cmdstanpy - INFO - Chain [1] start processing
# 16:39:26 - cmdstanpy - INFO - Chain [1] done processing
# 16:39:26 - cmdstanpy - INFO - Chain [1] start processing
# 16:39:27 - cmdstanpy - INFO - Chain [1] done processing
# 16:39:28 - cmdstanpy - INFO - Chain [1] start processing
# 16:39:28 - cmdstanpy - INFO - Chain [1] done processing
# 16:39:29 - cmdstanpy - INFO - Chain [1] start processing
# 16:39:29 - cmdstanpy - INFO - Chain [1] done processing
# 16:39:30 - cmdstanpy - INFO - Chain [1] start processing
# 16:39:31 - cmdstanpy - INFO - Chain [1] done processing
# 16:39:31 - cmdstanpy - INFO - Chain [1] start processing
# 16:39:32 - cmdstanpy - INFO - Chain [1] done processing
# 16:39:32 - cmdstanpy - INFO - Chain [1] start processing
# 16:39:33 - cmdstanpy - INFO - Chain [1] done processing
# 16:39:34 - cmdstanpy - INFO - Chain [1] start processing
# 16:39:34 - cmdstanpy - INFO - Chain [1] done processing
# 16:39:35 - cmdstanpy - INFO - Chain [1] start processing
# 16:39:36 - cmdstanpy - INFO - Chain [1] done processing
# 16:39:36 - cmdstanpy - INFO - Chain [1] start processing
# 16:39:37 - cmdstanpy - INFO - Chain [1] done processing
# 16:39:37 - cmdstanpy - INFO - Chain [1] start processing
# 16:39:38 - cmdstanpy - INFO - Chain [1] done processing
# 16:39:39 - cmdstanpy - INFO - Chain [1] start processing
# 16:39:39 - cmdstanpy - INFO - Chain [1] done processing
# 16:39:40 - cmdstanpy - INFO - Chain [1] start processing
# 16:39:41 - cmdstanpy - INFO - Chain [1] done processing
# 16:39:41 - cmdstanpy - INFO - Chain [1] start processing
# 16:39:42 - cmdstanpy - INFO - Chain [1] done processing
# 16:39:43 - cmdstanpy - INFO - Chain [1] start processing
# 16:39:43 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_30663/1288504425.py:35: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   forecasts = data2.groupby(["country", "store", "product"], group_keys=False).apply(forecast_sales)

# %%
# forecasts = forecasts[forecasts['ds']<='2016-12-31']

# %%
# forecasts[forecasts['ds']>'2016-12-31']
# Out:
# Empty DataFrame
# Columns: [ds, yhat, yhat_lower, yhat_upper, country, store, product]
# Index: []

# %%
import pandas as pd
import matplotlib.pyplot as plt
from prophet import Prophet

# Load training and test data
train_data = data2.copy()  # Replace with actual file path
# test_data = pd.read_csv("your_test_data.csv")  # Replace with actual file path

# Convert date to datetime format
train_data["date"] = pd.to_datetime(train_data["date"])
test_data["date"] = pd.to_datetime(test_data["date"])

# Prepare test dataset format
test_data["num_sold"] = None  # Placeholder for predictions

# Function to train Prophet and predict on test data
def forecast_sales(group, test_group):
    # Rename columns for Prophet
    prophet_df = group.rename(columns={"date": "ds", "num_sold": "y"})
    
    # Initialize and train Prophet model
    model = Prophet()
    model.fit(prophet_df)
    
    # Use test dates for forecasting
    future = test_group[["date"]].rename(columns={"date": "ds"})
    forecast = model.predict(future)
    
    # Merge predictions with test data
    test_group["predicted_num_sold"] = forecast["yhat"].values
    test_group["yhat_lower"] = forecast["yhat_lower"].values
    test_group["yhat_upper"] = forecast["yhat_upper"].values
    
    return test_group

# Apply forecasting for each (country, store, product) in test data
predictions = []
grouped_train = train_data.groupby(["country", "store", "product"])
grouped_test = test_data.groupby(["country", "store", "product"])

for group_key, train_group in grouped_train:
    if group_key in grouped_test.groups:
        test_group = grouped_test.get_group(group_key)
        pred = forecast_sales(train_group, test_group)
        predictions.append(pred)

# Combine all predictions
predictions_df = pd.concat(predictions)

# Save results
predictions_df.to_csv("test_predictions.csv", index=False)
print(predictions_df.head())  # Display first few rows
# Out:
# /tmp/ipykernel_30663/1726130084.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["predicted_num_sold"] = forecast["yhat"].values
# /tmp/ipykernel_30663/1726130084.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_lower"] = forecast["yhat_lower"].values
# /tmp/ipykernel_30663/1726130084.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_upper"] = forecast["yhat_upper"].values
# 16:52:16 - cmdstanpy - INFO - Chain [1] start processing
# 16:52:17 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_30663/1726130084.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["predicted_num_sold"] = forecast["yhat"].values
# /tmp/ipykernel_30663/1726130084.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_lower"] = forecast["yhat_lower"].values
# /tmp/ipykernel_30663/1726130084.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_upper"] = forecast["yhat_upper"].values
# 16:52:17 - cmdstanpy - INFO - Chain [1] start processing
# 16:52:18 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_30663/1726130084.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["predicted_num_sold"] = forecast["yhat"].values
# /tmp/ipykernel_30663/1726130084.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_lower"] = forecast["yhat_lower"].values
# /tmp/ipykernel_30663/1726130084.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_upper"] = forecast["yhat_upper"].values
# 16:52:18 - cmdstanpy - INFO - Chain [1] start processing
# 16:52:19 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_30663/1726130084.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["predicted_num_sold"] = forecast["yhat"].values
# /tmp/ipykernel_30663/1726130084.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_lower"] = forecast["yhat_lower"].values
# /tmp/ipykernel_30663/1726130084.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_upper"] = forecast["yhat_upper"].values
# 16:52:20 - cmdstanpy - INFO - Chain [1] start processing
# 16:52:20 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_30663/1726130084.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["predicted_num_sold"] = forecast["yhat"].values
# /tmp/ipykernel_30663/1726130084.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_lower"] = forecast["yhat_lower"].values
# /tmp/ipykernel_30663/1726130084.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_upper"] = forecast["yhat_upper"].values
# 16:52:21 - cmdstanpy - INFO - Chain [1] start processing
# 16:52:21 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_30663/1726130084.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["predicted_num_sold"] = forecast["yhat"].values
# /tmp/ipykernel_30663/1726130084.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_lower"] = forecast["yhat_lower"].values
# /tmp/ipykernel_30663/1726130084.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_upper"] = forecast["yhat_upper"].values
# 16:52:22 - cmdstanpy - INFO - Chain [1] start processing
# 16:52:23 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_30663/1726130084.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["predicted_num_sold"] = forecast["yhat"].values
# /tmp/ipykernel_30663/1726130084.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_lower"] = forecast["yhat_lower"].values
# /tmp/ipykernel_30663/1726130084.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_upper"] = forecast["yhat_upper"].values
# 16:52:23 - cmdstanpy - INFO - Chain [1] start processing
# 16:52:24 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_30663/1726130084.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["predicted_num_sold"] = forecast["yhat"].values
# /tmp/ipykernel_30663/1726130084.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_lower"] = forecast["yhat_lower"].values
# /tmp/ipykernel_30663/1726130084.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_upper"] = forecast["yhat_upper"].values
# 16:52:24 - cmdstanpy - INFO - Chain [1] start processing
# 16:52:25 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_30663/1726130084.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["predicted_num_sold"] = forecast["yhat"].values
# /tmp/ipykernel_30663/1726130084.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_lower"] = forecast["yhat_lower"].values
# /tmp/ipykernel_30663/1726130084.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_upper"] = forecast["yhat_upper"].values
# 16:52:26 - cmdstanpy - INFO - Chain [1] start processing
# 16:52:26 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_30663/1726130084.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["predicted_num_sold"] = forecast["yhat"].values
# /tmp/ipykernel_30663/1726130084.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_lower"] = forecast["yhat_lower"].values
# /tmp/ipykernel_30663/1726130084.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_upper"] = forecast["yhat_upper"].values
# 16:52:27 - cmdstanpy - INFO - Chain [1] start processing
# 16:52:27 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_30663/1726130084.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["predicted_num_sold"] = forecast["yhat"].values
# /tmp/ipykernel_30663/1726130084.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_lower"] = forecast["yhat_lower"].values
# /tmp/ipykernel_30663/1726130084.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_upper"] = forecast["yhat_upper"].values
# 16:52:28 - cmdstanpy - INFO - Chain [1] start processing
# 16:52:29 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_30663/1726130084.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["predicted_num_sold"] = forecast["yhat"].values
# /tmp/ipykernel_30663/1726130084.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_lower"] = forecast["yhat_lower"].values
# /tmp/ipykernel_30663/1726130084.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_upper"] = forecast["yhat_upper"].values
# 16:52:29 - cmdstanpy - INFO - Chain [1] start processing
# 16:52:30 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_30663/1726130084.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["predicted_num_sold"] = forecast["yhat"].values
# /tmp/ipykernel_30663/1726130084.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_lower"] = forecast["yhat_lower"].values
# /tmp/ipykernel_30663/1726130084.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_upper"] = forecast["yhat_upper"].values
# 16:52:31 - cmdstanpy - INFO - Chain [1] start processing
# 16:52:31 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_30663/1726130084.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["predicted_num_sold"] = forecast["yhat"].values
# /tmp/ipykernel_30663/1726130084.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_lower"] = forecast["yhat_lower"].values
# /tmp/ipykernel_30663/1726130084.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_upper"] = forecast["yhat_upper"].values
# 16:52:32 - cmdstanpy - INFO - Chain [1] start processing
# 16:52:33 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_30663/1726130084.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["predicted_num_sold"] = forecast["yhat"].values
# /tmp/ipykernel_30663/1726130084.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_lower"] = forecast["yhat_lower"].values
# /tmp/ipykernel_30663/1726130084.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_upper"] = forecast["yhat_upper"].values
# 16:52:33 - cmdstanpy - INFO - Chain [1] start processing
# 16:52:34 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_30663/1726130084.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["predicted_num_sold"] = forecast["yhat"].values
# /tmp/ipykernel_30663/1726130084.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_lower"] = forecast["yhat_lower"].values
# /tmp/ipykernel_30663/1726130084.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_upper"] = forecast["yhat_upper"].values
# 16:52:34 - cmdstanpy - INFO - Chain [1] start processing
# 16:52:35 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_30663/1726130084.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["predicted_num_sold"] = forecast["yhat"].values
# /tmp/ipykernel_30663/1726130084.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_lower"] = forecast["yhat_lower"].values
# /tmp/ipykernel_30663/1726130084.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_upper"] = forecast["yhat_upper"].values
# 16:52:36 - cmdstanpy - INFO - Chain [1] start processing
# 16:52:38 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_30663/1726130084.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["predicted_num_sold"] = forecast["yhat"].values
# /tmp/ipykernel_30663/1726130084.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_lower"] = forecast["yhat_lower"].values
# /tmp/ipykernel_30663/1726130084.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_upper"] = forecast["yhat_upper"].values
# 16:52:38 - cmdstanpy - INFO - Chain [1] start processing
# 16:52:39 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_30663/1726130084.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["predicted_num_sold"] = forecast["yhat"].values
# /tmp/ipykernel_30663/1726130084.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_lower"] = forecast["yhat_lower"].values
# /tmp/ipykernel_30663/1726130084.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_upper"] = forecast["yhat_upper"].values
# 16:52:40 - cmdstanpy - INFO - Chain [1] start processing
# 16:52:40 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_30663/1726130084.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["predicted_num_sold"] = forecast["yhat"].values
# /tmp/ipykernel_30663/1726130084.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_lower"] = forecast["yhat_lower"].values
# /tmp/ipykernel_30663/1726130084.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_upper"] = forecast["yhat_upper"].values
# 16:52:41 - cmdstanpy - INFO - Chain [1] start processing
# 16:52:42 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_30663/1726130084.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["predicted_num_sold"] = forecast["yhat"].values
# /tmp/ipykernel_30663/1726130084.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_lower"] = forecast["yhat_lower"].values
# /tmp/ipykernel_30663/1726130084.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_upper"] = forecast["yhat_upper"].values
# 16:52:42 - cmdstanpy - INFO - Chain [1] start processing
# 16:52:43 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_30663/1726130084.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["predicted_num_sold"] = forecast["yhat"].values
# /tmp/ipykernel_30663/1726130084.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_lower"] = forecast["yhat_lower"].values
# /tmp/ipykernel_30663/1726130084.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_upper"] = forecast["yhat_upper"].values
# 16:52:44 - cmdstanpy - INFO - Chain [1] start processing
# 16:52:44 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_30663/1726130084.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["predicted_num_sold"] = forecast["yhat"].values
# /tmp/ipykernel_30663/1726130084.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_lower"] = forecast["yhat_lower"].values
# /tmp/ipykernel_30663/1726130084.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_upper"] = forecast["yhat_upper"].values
# 16:52:45 - cmdstanpy - INFO - Chain [1] start processing
# 16:52:45 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_30663/1726130084.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["predicted_num_sold"] = forecast["yhat"].values
# /tmp/ipykernel_30663/1726130084.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_lower"] = forecast["yhat_lower"].values
# /tmp/ipykernel_30663/1726130084.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_upper"] = forecast["yhat_upper"].values
# 16:52:46 - cmdstanpy - INFO - Chain [1] start processing
# 16:52:47 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_30663/1726130084.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["predicted_num_sold"] = forecast["yhat"].values
# /tmp/ipykernel_30663/1726130084.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_lower"] = forecast["yhat_lower"].values
# /tmp/ipykernel_30663/1726130084.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_upper"] = forecast["yhat_upper"].values
# 16:52:47 - cmdstanpy - INFO - Chain [1] start processing
# 16:52:48 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_30663/1726130084.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["predicted_num_sold"] = forecast["yhat"].values
# /tmp/ipykernel_30663/1726130084.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_lower"] = forecast["yhat_lower"].values
# /tmp/ipykernel_30663/1726130084.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_upper"] = forecast["yhat_upper"].values
# 16:52:48 - cmdstanpy - INFO - Chain [1] start processing
# 16:52:49 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_30663/1726130084.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["predicted_num_sold"] = forecast["yhat"].values
# /tmp/ipykernel_30663/1726130084.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_lower"] = forecast["yhat_lower"].values
# /tmp/ipykernel_30663/1726130084.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_upper"] = forecast["yhat_upper"].values
# 16:52:50 - cmdstanpy - INFO - Chain [1] start processing
# 16:52:51 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_30663/1726130084.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["predicted_num_sold"] = forecast["yhat"].values
# /tmp/ipykernel_30663/1726130084.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_lower"] = forecast["yhat_lower"].values
# /tmp/ipykernel_30663/1726130084.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_upper"] = forecast["yhat_upper"].values
# 16:52:51 - cmdstanpy - INFO - Chain [1] start processing
# 16:52:52 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_30663/1726130084.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["predicted_num_sold"] = forecast["yhat"].values
# /tmp/ipykernel_30663/1726130084.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_lower"] = forecast["yhat_lower"].values
# /tmp/ipykernel_30663/1726130084.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_upper"] = forecast["yhat_upper"].values
# 16:52:52 - cmdstanpy - INFO - Chain [1] start processing
# 16:52:53 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_30663/1726130084.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["predicted_num_sold"] = forecast["yhat"].values
# /tmp/ipykernel_30663/1726130084.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_lower"] = forecast["yhat_lower"].values
# /tmp/ipykernel_30663/1726130084.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_upper"] = forecast["yhat_upper"].values
# 16:52:53 - cmdstanpy - INFO - Chain [1] start processing
# 16:52:54 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_30663/1726130084.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["predicted_num_sold"] = forecast["yhat"].values
# /tmp/ipykernel_30663/1726130084.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_lower"] = forecast["yhat_lower"].values
# /tmp/ipykernel_30663/1726130084.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_upper"] = forecast["yhat_upper"].values
# 16:52:54 - cmdstanpy - INFO - Chain [1] start processing
# 16:52:55 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_30663/1726130084.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["predicted_num_sold"] = forecast["yhat"].values
# /tmp/ipykernel_30663/1726130084.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_lower"] = forecast["yhat_lower"].values
# /tmp/ipykernel_30663/1726130084.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_upper"] = forecast["yhat_upper"].values
# 16:52:56 - cmdstanpy - INFO - Chain [1] start processing
# 16:52:57 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_30663/1726130084.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["predicted_num_sold"] = forecast["yhat"].values
# /tmp/ipykernel_30663/1726130084.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_lower"] = forecast["yhat_lower"].values
# /tmp/ipykernel_30663/1726130084.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_upper"] = forecast["yhat_upper"].values
# 16:52:57 - cmdstanpy - INFO - Chain [1] start processing
# 16:52:58 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_30663/1726130084.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["predicted_num_sold"] = forecast["yhat"].values
# /tmp/ipykernel_30663/1726130084.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_lower"] = forecast["yhat_lower"].values
# /tmp/ipykernel_30663/1726130084.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_upper"] = forecast["yhat_upper"].values
# 16:52:58 - cmdstanpy - INFO - Chain [1] start processing
# 16:52:59 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_30663/1726130084.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["predicted_num_sold"] = forecast["yhat"].values
# /tmp/ipykernel_30663/1726130084.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_lower"] = forecast["yhat_lower"].values
# /tmp/ipykernel_30663/1726130084.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_upper"] = forecast["yhat_upper"].values
# 16:52:59 - cmdstanpy - INFO - Chain [1] start processing
# 16:53:00 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_30663/1726130084.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["predicted_num_sold"] = forecast["yhat"].values
# /tmp/ipykernel_30663/1726130084.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_lower"] = forecast["yhat_lower"].values
# /tmp/ipykernel_30663/1726130084.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_upper"] = forecast["yhat_upper"].values
# 16:53:01 - cmdstanpy - INFO - Chain [1] start processing
# 16:53:02 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_30663/1726130084.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["predicted_num_sold"] = forecast["yhat"].values
# /tmp/ipykernel_30663/1726130084.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_lower"] = forecast["yhat_lower"].values
# /tmp/ipykernel_30663/1726130084.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_upper"] = forecast["yhat_upper"].values
# 16:53:02 - cmdstanpy - INFO - Chain [1] start processing
# 16:53:03 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_30663/1726130084.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["predicted_num_sold"] = forecast["yhat"].values
# /tmp/ipykernel_30663/1726130084.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_lower"] = forecast["yhat_lower"].values
# /tmp/ipykernel_30663/1726130084.py:32: SettingWithCopyWarning:
# ...
# /tmp/ipykernel_30663/1726130084.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["predicted_num_sold"] = forecast["yhat"].values
# /tmp/ipykernel_30663/1726130084.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_lower"] = forecast["yhat_lower"].values
# /tmp/ipykernel_30663/1726130084.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_upper"] = forecast["yhat_upper"].values
# 16:53:50 - cmdstanpy - INFO - Chain [1] start processing
# 16:53:51 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_30663/1726130084.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["predicted_num_sold"] = forecast["yhat"].values
# /tmp/ipykernel_30663/1726130084.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_lower"] = forecast["yhat_lower"].values
# /tmp/ipykernel_30663/1726130084.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_upper"] = forecast["yhat_upper"].values
# 16:53:51 - cmdstanpy - INFO - Chain [1] start processing
# 16:53:51 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_30663/1726130084.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["predicted_num_sold"] = forecast["yhat"].values
# /tmp/ipykernel_30663/1726130084.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_lower"] = forecast["yhat_lower"].values
# /tmp/ipykernel_30663/1726130084.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_upper"] = forecast["yhat_upper"].values
# 16:53:52 - cmdstanpy - INFO - Chain [1] start processing
# 16:53:53 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_30663/1726130084.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["predicted_num_sold"] = forecast["yhat"].values
# /tmp/ipykernel_30663/1726130084.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_lower"] = forecast["yhat_lower"].values
# /tmp/ipykernel_30663/1726130084.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_upper"] = forecast["yhat_upper"].values
# 16:53:53 - cmdstanpy - INFO - Chain [1] start processing
# 16:53:54 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_30663/1726130084.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["predicted_num_sold"] = forecast["yhat"].values
# /tmp/ipykernel_30663/1726130084.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_lower"] = forecast["yhat_lower"].values
# /tmp/ipykernel_30663/1726130084.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_upper"] = forecast["yhat_upper"].values
# 16:53:54 - cmdstanpy - INFO - Chain [1] start processing
# 16:53:55 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_30663/1726130084.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["predicted_num_sold"] = forecast["yhat"].values
# /tmp/ipykernel_30663/1726130084.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_lower"] = forecast["yhat_lower"].values
# /tmp/ipykernel_30663/1726130084.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_upper"] = forecast["yhat_upper"].values
# 16:53:55 - cmdstanpy - INFO - Chain [1] start processing
# 16:53:56 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_30663/1726130084.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["predicted_num_sold"] = forecast["yhat"].values
# /tmp/ipykernel_30663/1726130084.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_lower"] = forecast["yhat_lower"].values
# /tmp/ipykernel_30663/1726130084.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_upper"] = forecast["yhat_upper"].values
# 16:53:56 - cmdstanpy - INFO - Chain [1] start processing
# 16:53:57 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_30663/1726130084.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["predicted_num_sold"] = forecast["yhat"].values
# /tmp/ipykernel_30663/1726130084.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_lower"] = forecast["yhat_lower"].values
# /tmp/ipykernel_30663/1726130084.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_upper"] = forecast["yhat_upper"].values
# 16:53:58 - cmdstanpy - INFO - Chain [1] start processing
# 16:53:58 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_30663/1726130084.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["predicted_num_sold"] = forecast["yhat"].values
# /tmp/ipykernel_30663/1726130084.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_lower"] = forecast["yhat_lower"].values
# /tmp/ipykernel_30663/1726130084.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_upper"] = forecast["yhat_upper"].values
# 16:53:59 - cmdstanpy - INFO - Chain [1] start processing
# 16:53:59 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_30663/1726130084.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["predicted_num_sold"] = forecast["yhat"].values
# /tmp/ipykernel_30663/1726130084.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_lower"] = forecast["yhat_lower"].values
# /tmp/ipykernel_30663/1726130084.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_upper"] = forecast["yhat_upper"].values
# 16:54:00 - cmdstanpy - INFO - Chain [1] start processing
# 16:54:00 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_30663/1726130084.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["predicted_num_sold"] = forecast["yhat"].values
# /tmp/ipykernel_30663/1726130084.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_lower"] = forecast["yhat_lower"].values
# /tmp/ipykernel_30663/1726130084.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_upper"] = forecast["yhat_upper"].values
# 16:54:01 - cmdstanpy - INFO - Chain [1] start processing
# 16:54:02 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_30663/1726130084.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["predicted_num_sold"] = forecast["yhat"].values
# /tmp/ipykernel_30663/1726130084.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_lower"] = forecast["yhat_lower"].values
# /tmp/ipykernel_30663/1726130084.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_group["yhat_upper"] = forecast["yhat_upper"].values
#          id       date country              store            product num_sold  \
# 0    230130 2017-01-01  Canada  Discount Stickers  Holographic Goose     None
# 90   230220 2017-01-02  Canada  Discount Stickers  Holographic Goose     None
# 180  230310 2017-01-03  Canada  Discount Stickers  Holographic Goose     None
# 270  230400 2017-01-04  Canada  Discount Stickers  Holographic Goose     None
# 360  230490 2017-01-05  Canada  Discount Stickers  Holographic Goose     None
#
#      predicted_num_sold    yhat_lower    yhat_upper
# 0                   0.0 -1.342524e-09  1.280042e-09
# 90                  0.0 -1.219854e-09  1.197334e-09
# 180                 0.0 -1.243511e-09  1.332886e-09
# 270                 0.0 -1.223548e-09  1.293185e-09
# 360                 0.0 -1.317902e-09  1.248525e-09

# %%
test_data = pd.read_csv('test.csv')

# %%
# import pandas as pd
# import numpy as np

# # Load actual test data and predictions
# test_actual = pd.read_csv("your_test_data.csv")  # Replace with actual file path
# test_predictions = pd.read_csv("test_predictions.csv")  # File from previous Prophet predictions

# # Merge actual and predicted values
# df_eval = test_actual.merge(test_predictions[["date", "country", "store", "product", "predicted_num_sold"]], 
#                             on=["date", "country", "store", "product"], how="left")

# # Compute absolute percentage error (avoid division by zero)
# df_eval["APE"] = np.abs((df_eval["num_sold"] - df_eval["predicted_num_sold"]) / df_eval["num_sold"])
# df_eval = df_eval.replace([np.inf, -np.inf], np.nan)  # Handle cases where actual num_sold is 0
# df_eval = df_eval.dropna(subset=["APE"])  # Drop rows where MAPE couldn't be computed

# # Compute overall MAPE
# overall_mape = df_eval["APE"].mean() * 100
# print(f"Overall MAPE: {overall_mape:.2f}%")

# # Compute MAPE per (country, store, product)
# group_mape = df_eval.groupby(["country", "store", "product"])["APE"].mean() * 100
# group_mape = group_mape.reset_index().rename(columns={"APE": "MAPE"})

# # Save MAPE results
# group_mape.to_csv("mape_per_group.csv", index=False)
# print(group_mape.head())  # Display MAPE per group

# %%
import numpy as np

# %%
tested_df = pd.read_csv("test_predictions.csv")
tested_df.drop(columns=["num_sold"],inplace=True)
tested_df['predicted_num_sold'] = np.ceil(tested_df['predicted_num_sold']).astype(int)
tested_df.rename(columns={"predicted_num_sold":"num_sold"},inplace=True)
tested_df = tested_df[["id","num_sold"]]
tested_df = tested_df.sort_values(by="id")

# %%
tested_df
# Out:
#            id  num_sold
# 0      230130         0
# 1095   230131       818
# 2190   230132       675
# 3285   230133       380
# 4380   230134       451
# ...       ...       ...
# 88694  328675       377
# 89789  328676      2062
# 90884  328677      1446
# 91979  328678      1049
# 93074  328679      1271
#
# [98550 rows x 2 columns]

# %%
tested_df.describe()
# Out:
#                   id      num_sold
# count   98550.000000  98550.000000
# mean   279404.500000    614.664495
# std     28449.078852    524.318380
# min    230130.000000      0.000000
# 25%    254767.250000    188.000000
# 50%    279404.500000    513.000000
# 75%    304041.750000    930.000000
# max    328679.000000   3341.000000

# %%
tested_df[['id','num_sold']].to_csv('submission1.csv')
